# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import os
import datetime as dt

main_path = os.getcwd()

#weekly return
df_r = pd.read_pickle(main_path+'\\data\\future_return_bear.pkl')
df_r = df_r.fillna(method='ffill').dropna()
 #load price (exchange rate) data
df_P = pd.read_pickle(main_path+'\\data\\future_price_bear.pkl')
df_P = df_P.fillna(method='ffill').drop(df_P.index[0])

# %%
plt.figure(figsize=(10,8))
plt.plot(df_r, label=df_r.columns)
plt.legend(fontsize='small')
plt.show()

# %%
inception = 105
t_date = df_P.index
t = np.array(range(len(t_date)))
rebalance_dates = t[inception:]
n = df_P.shape[1]

# %%
for i in range(52*2):
    trade_date = rebalance_dates[i]
    start_date = 0
    mu = np.array(preds)[i,:]
    print(mu)
    V = np.array(df_r)[start_date : trade_date,:].T.dot(np.array(df_r)[start_date : trade_date,:]) - mu.dot(mu.T)
    try:
        U = np.linalg.cholesky(V)
    except np.linalg.LinAlgError as e:
        print('********', e, '********')
        print(V)
# Out:
# [-0.009606883092922111 0.022653044964201542 -0.17912766166644706
#  0.01198414868770952 -0.002509112862505251 -0.008762840588062792]
# ******** Matrix is not positive definite ********
# [[ 0.01442168 -0.02737929 -0.02064245 -0.02398344 -0.00451475 -0.03177272
#   -0.02940696 -0.04370103]
#  [-0.02737929  0.08477595  0.02731796 -0.01235318 -0.01457681 -0.03321525
#   -0.03476676 -0.02176337]
#  [-0.02064245  0.02731796  0.85905265  0.02607267 -0.01570362 -0.03432017
#   -0.03722046 -0.03566603]
#  [-0.02398344 -0.01235318  0.02607267  0.07521207  0.01114101 -0.03488302
#   -0.03783752  0.00607321]
#  [-0.00451475 -0.01457681 -0.01570362  0.01114101  0.0637749  -0.03495201
#   -0.03782322  0.01008459]
#  [-0.03177272 -0.03321525 -0.03432017 -0.03488302 -0.03495201 -0.03258649
#   -0.03213662 -0.03539117]
#  [-0.02940696 -0.03476676 -0.03722046 -0.03783752 -0.03782322 -0.03213662
#   -0.03087981 -0.04010909]
#  [-0.04370103 -0.02176337 -0.03566603  0.00607321  0.01008459 -0.03539117
# ...

# %%
try:
    U = np.linalg.cholesky(V)
except np.linalg.LinAlgError as e:
    print('********', e, '********')
    print(V)

# %%
#generate mu and V
r_d = 0 #rate of decay = 0
w = (1 - r_d)**np.array(range(250))
w = w[::-1]/np.sum(w)

mu = r.T.dot(w)
V1 = r.T.dot(np.diag(w)).dot(r) - mu.dot(mu)

# %%
w
# Out:
# array([0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
# ...

# %%
try:
    U = np.linalg.cholesky(V1)
except np.linalg.LinAlgError as e:
    print('********', e, '********')
    print(V1)
